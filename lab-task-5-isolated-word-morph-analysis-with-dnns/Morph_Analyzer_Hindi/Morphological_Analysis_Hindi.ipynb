# %% [markdown]
# # Multi-Task Deep Morph Analyzer

# %% [markdown]
# A multi-task learning CNN-RNN model combined together with the potential of task-optimized phonetic features to predict the Lemma, POS category, Gender, Number, Person, Case, and Tense-aspect-mood (TAM) of Hindi words.

# %% [markdown]
# We will install the Hindi Dependency Treebank from http://ltrc.iiit.ac.in/hutb_release/

# %%
# !wget http://ltrc.iiit.ac.in/hutb_release/HDTB_pre_release_version-0.05.zip
# Out:
# --2021-03-20 07:11:14--  http://ltrc.iiit.ac.in/hutb_release/HDTB_pre_release_version-0.05.zip
# Resolving ltrc.iiit.ac.in (ltrc.iiit.ac.in)... 196.12.53.50
# Connecting to ltrc.iiit.ac.in (ltrc.iiit.ac.in)|196.12.53.50|:80... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: http://cdn.iiit.ac.in/cdn/ltrc.iiit.ac.in/hutb_release/HDTB_pre_release_version-0.05.zip [following]
# --2021-03-20 07:11:15--  http://cdn.iiit.ac.in/cdn/ltrc.iiit.ac.in/hutb_release/HDTB_pre_release_version-0.05.zip
# Resolving cdn.iiit.ac.in (cdn.iiit.ac.in)... 14.139.82.19
# Connecting to cdn.iiit.ac.in (cdn.iiit.ac.in)|14.139.82.19|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 628493531 (599M) [application/zip]
# Saving to: ‘HDTB_pre_release_version-0.05.zip’
#
# HDTB_pre_release_ve 100%[===================>] 599.38M  4.00MB/s    in 90s
#
# 2021-03-20 07:12:45 (6.67 MB/s) - ‘HDTB_pre_release_version-0.05.zip’ saved [628493531/628493531]

# %% [markdown]
# After downloading the dataset, we will unzip them and place in "datasets" folder

# %%
# !unzip /content/HDTB_pre_release_version-0.05.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2494108_date_1_6_2004.dat
#   inflating: HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2494312_date_1_6_2004.dat
#   inflating: HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2571134_date_4_7_2004.dat
#   inflating: HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2561717_date_30_6_2004.dat
#   inflating: HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2501730_date_4_6_2004.dat
#   inflating: HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2506457_date_6_6_2004.dat
# ...

# %% [markdown]
# Clone the gitHub repository: https://github.com/NLPRL/MTDMA-Morph-Analyzer.git

# %%
# !git clone https://github.com/NLPRL/MTDMA-Morph-Analyzer.git
# Out:
# Cloning into 'MTDMA-Morph-Analyzer'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 516 (delta 42), reused 33 (delta 33), pack-reused 471
# Receiving objects: 100% (516/516), 28.97 MiB | 32.35 MiB/s, done.
# Resolving deltas: 100% (245/245), done.

# %% [markdown]
# Move into the MTDMA-Morph-Analyzer directory cloned earlier

# %%
cd /content/MTDMA-Morph-Analyzer
# Out:
# /content/MTDMA-Morph-Analyzer

# %% [markdown]
# Install the libraries as mentioned below:
# - scikit-learn==0.20.3
# - tensorflow==1.15.0
# - keras==2.1.6
# - tensorflow-gpu==1.15
# - matplotlib==2.2.2

# %%
# !pip install matplotlib==2.2.2

# %%
# !pip install --upgrade scikit-learn==0.20.3
# Out:
# ...
#      |████████████████████████████████| 5.4MB 9.3MB/s
# ...
# ERROR: umap-learn 0.5.1 has requirement scikit-learn>=0.22, but you'll have scikit-learn 0.20.3 which is incompatible.
# ...
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
# ...

# %%
# !pip3 install tensorflow==1.15.0
# Out:
# ...
#      |████████████████████████████████| 412.3MB 40kB/s
# ...
#      |████████████████████████████████| 51kB 6.1MB/s
# ...
#      |████████████████████████████████| 3.8MB 41.3MB/s
# ...
#      |████████████████████████████████| 512kB 36.8MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp37-none-any.whl size=7540 sha256=cc2e848096d48a942e8bb552db67d381b0c9e73b392c6d4b7470d3ce6754fe62
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.12.1 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
# ...

# %%
# !pip install keras==2.1.6
# Out:
# ...
#      |████████████████████████████████| 348kB 7.9MB/s
# ...
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# ...

# %%
# !pip install tensorflow-gpu==1.15
# Out:
# ...
#      |████████████████████████████████| 411.5MB 36kB/s
# ...

# %% [markdown]
# Train the model keeping language = "hindi" , mode = "train", phonetic = "true", freezing = "true"

# %%
# !python main.py --lang hindi --mode train --phonetic true --freezing true
# Out:
# Using TensorFlow backend.
# tcmalloc: large alloc 4456816640 bytes == 0x56184c1de000 @  0x7f9b7ea58001 0x7f9b7c4d654f 0x7f9b7c526b58 0x7f9b7c52ab17 0x7f9b7c5c9203 0x56182553c050 0x56182553bde0 0x5618255b0244 0x56182553d69a 0x5618255afe50 0x56182553d69a 0x5618255abc9e 0x5618255aae0d 0x56182553d77a 0x5618255aba45 0x5618255aab0e 0x5618255aa813 0x561825674592 0x56182567490d 0x5618256747b6 0x56182564c103 0x56182564bdac 0x7f9b7d840bf7 0x56182564bc8a
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %% [markdown]
# ## Training Accuracy and Validation Accuracy
#
# * output0_acc: 0.8566 - output1_acc: 0.8077 - output2_acc: 0.8443 - output3_acc: 0.8618 - output4_acc: 0.8506 - output5_acc: 0.8694 - val_output0_acc: 0.9424 - val_output1_acc: 0.9062 - val_output2_acc: 0.9088 - val_output3_acc: 0.9217 - val_output4_acc: 0.9196 - val_output5_acc: 0.9468
# * output0_acc: 0.9353 - output1_acc: 0.8944 - output2_acc: 0.9061 - output3_acc: 0.9197 - output4_acc: 0.9184 - output5_acc: 0.9409 - val_output0_acc: 0.9596 - val_output1_acc: 0.9267 - val_output2_acc: 0.9292 - val_output3_acc: 0.9408 - val_output4_acc: 0.9366 - val_output5_acc: 0.9592
# * output0_acc: 0.9496 - output1_acc: 0.9121 - output2_acc: 0.9211 - output3_acc: 0.9338 - output4_acc: 0.9313 - output5_acc: 0.9538 - val_output0_acc: 0.9661 - val_output1_acc: 0.9341 - val_output2_acc: 0.9369 - val_output3_acc: 0.9512 - val_output4_acc: 0.9450 - val_output5_acc: 0.9684
# * output0_acc: 0.9556 - output1_acc: 0.9206 - output2_acc: 0.9287 - output3_acc: 0.9401 - output4_acc: 0.9370 - output5_acc: 0.9604 - val_output0_acc: 0.9690 - val_output1_acc: 0.9407 - val_output2_acc: 0.9421 - val_output3_acc: 0.9522 - val_output4_acc: 0.9481 - val_output5_acc: 0.9715

# %% [markdown]
# ## Test the Model

# %%
# !python main.py --lang hindi --mode test --phonetic true --freezing true
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:125: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:127: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# ...

# %% [markdown]
# * Average precision score, micro-averaged over all classes: 0.05985533704201262
# * Average precision score, micro-averaged over all classes: 0.16708091733873556
# * Average precision score, micro-averaged over all classes: 0.15658506435608013
# * Average precision score, micro-averaged over all classes: 0.08815003700210601
# * Average precision score, micro-averaged over all classes: 0.12808810967424328
# * Average precision score, micro-averaged over all classes: 0.6732071283805671

# %%
# !python main.py --lang hindi --mode predict --phonetic true --freezing true
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:125: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:127: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# ...
