# %% [markdown]
# # Multi-Task Deep Morph Analyzer Urdu

# %% [markdown]
# ---

# %% [markdown]
# Download the dataset from http://ltrc.iiit.ac.in/hutb_release/UDTB_pre_release_version-0.01.zip

# %%
# !wget http://ltrc.iiit.ac.in/hutb_release/UDTB_pre_release_version-0.01.zip
# Out:
# --2021-03-20 09:56:46--  http://ltrc.iiit.ac.in/hutb_release/UDTB_pre_release_version-0.01.zip
# Resolving ltrc.iiit.ac.in (ltrc.iiit.ac.in)... 196.12.53.50
# Connecting to ltrc.iiit.ac.in (ltrc.iiit.ac.in)|196.12.53.50|:80... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: http://cdn.iiit.ac.in/cdn/ltrc.iiit.ac.in/hutb_release/UDTB_pre_release_version-0.01.zip [following]
# --2021-03-20 09:56:46--  http://cdn.iiit.ac.in/cdn/ltrc.iiit.ac.in/hutb_release/UDTB_pre_release_version-0.01.zip
# Resolving cdn.iiit.ac.in (cdn.iiit.ac.in)... 14.139.82.19
# Connecting to cdn.iiit.ac.in (cdn.iiit.ac.in)|14.139.82.19|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 226297009 (216M) [application/zip]
# Saving to: ‘UDTB_pre_release_version-0.01.zip’
#
# UDTB_pre_release_ve 100%[===================>] 215.81M  6.46MB/s    in 29s
#
# 2021-03-20 09:57:16 (7.46 MB/s) - ‘UDTB_pre_release_version-0.01.zip’ saved [226297009/226297009]

# %% [markdown]
# Unzip the dataset folder in dataset folder in cloned repo

# %%
# !unzip /content/UDTB_pre_release_version-0.01.zip
# Out:
# Archive:  /content/UDTB_pre_release_version-0.01.zip
#    creating: UDTB_pre_release_version-0.01/
#    creating: UDTB_pre_release_version-0.01/Inter-chunk/
#    creating: UDTB_pre_release_version-0.01/Inter-chunk/CONLL/
#    creating: UDTB_pre_release_version-0.01/Inter-chunk/CONLL/utf/
#    creating: UDTB_pre_release_version-0.01/Inter-chunk/CONLL/utf/Testing/
#    creating: UDTB_pre_release_version-0.01/Inter-chunk/CONLL/utf/Testing/UTB-v1.0-set126/
#   inflating: UDTB_pre_release_version-0.01/Inter-chunk/CONLL/utf/Testing/UTB-v1.0-set126/fullnews_id_200345_date_07_25_2009.utf8.cml.V.tkn.cml_updated.mo.pos.chnk.prun.posn
#   inflating: UDTB_pre_release_version-0.01/Inter-chunk/CONLL/utf/Testing/UTB-v1.0-set126/fullnews_id_200351_date_07_25_2009.utf8.cml.V.tkn.cml_updated.mo.pos.chnk.prun.posn
#   inflating: UDTB_pre_release_version-0.01/Inter-chunk/CONLL/utf/Testing/UTB-v1.0-set126/fullnews_id_200346_date_07_25_2009.utf8.cml.V.tkn.cml_updated.mo.pos.chnk.prun.posn
# ...

# %% [markdown]
# Clone the repo https://github.com/NLPRL/MTDMA-Morph-Analyzer.git

# %%
# !git clone https://github.com/NLPRL/MTDMA-Morph-Analyzer.git
# Out:
# Cloning into 'MTDMA-Morph-Analyzer'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 516 (delta 42), reused 33 (delta 33), pack-reused 471
# Receiving objects: 100% (516/516), 28.97 MiB | 31.59 MiB/s, done.
# Resolving deltas: 100% (245/245), done.

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# Installing the required libraries

# %%
# !pip install --upgrade scikit-learn==0.20.3
# !pip3 install tensorflow==1.15.0
# !pip install keras==2.1.6
# !pip install tensorflow-gpu==1.15

# %%
cd /content/MTDMA-Morph-Analyzer
# Out:
# /content/MTDMA-Morph-Analyzer

# %% [markdown]
# ## Training and Validation of Model

# %%
# !python main.py --lang urdu --mode train --phonetic true --freezing true
# Out:
# Using TensorFlow backend.
# tcmalloc: large alloc 2299912192 bytes == 0x560b7f902000 @  0x7f2aa1d10001 0x7f2a9f78e54f 0x7f2a9f7deb58 0x7f2a9f7e2b17 0x7f2a9f881203 0x560b690b4050 0x560b690b3de0 0x560b69128244 0x560b690b569a 0x560b69127e50 0x560b690b569a 0x560b69123c9e 0x560b69122e0d 0x560b690b577a 0x560b69123a45 0x560b69122b0e 0x560b69122813 0x560b691ec592 0x560b691ec90d 0x560b691ec7b6 0x560b691c4103 0x560b691c3dac 0x7f2aa0af8bf7 0x560b691c3c8a
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %% [markdown]
# ## Accuracy and Validation Accuracy
#
# * output0_acc: 0.7846 - output1_acc: 0.7407 - output2_acc: 0.7784 - output3_acc: 0.8115 - output4_acc: 0.7658 - output5_acc: 0.8037 - val_output0_acc: 0.9078 - val_output1_acc: 0.8644 - val_output2_acc: 0.8814 - val_output3_acc: 0.9122 - val_output4_acc: 0.8541 - val_output5_acc: 0.9129
# * output0_acc: 0.8969 - output1_acc: 0.8483 - output2_acc: 0.8682 - output3_acc: 0.8911 - output4_acc: 0.8455 - output5_acc: 0.9045 - val_output0_acc: 0.9330 - val_output1_acc: 0.8879 - val_output2_acc: 0.9024 - val_output3_acc: 0.9328 - val_output4_acc: 0.8818 - val_output5_acc: 0.9410
# * output0_acc: 0.9153 - output1_acc: 0.8675 - output2_acc: 0.8875 - output3_acc: 0.9083 - output4_acc: 0.8617 - output5_acc: 0.9240 - val_output0_acc: 0.9420 - val_output1_acc: 0.9012 - val_output2_acc: 0.9125 - val_output3_acc: 0.9368 - val_output4_acc: 0.8935 - val_output5_acc: 0.9498
# * output0_acc: 0.9252 - output1_acc: 0.8774 - output2_acc: 0.8968 - output3_acc: 0.9174 - output4_acc: 0.8699 - output5_acc: 0.9342 - val_output0_acc: 0.9493 - val_output1_acc: 0.9048 - val_output2_acc: 0.9188 - val_output3_acc: 0.9462 - val_output4_acc: 0.8959 - val_output5_acc: 0.9560
# * output0_acc: 0.9313 - output1_acc: 0.8833 - output2_acc: 0.9032 - output3_acc: 0.9231 - output4_acc: 0.8740 - output5_acc: 0.9396 - val_output0_acc: 0.9495 - val_output1_acc: 0.9082 - val_output2_acc: 0.9192 - val_output3_acc: 0.9411 - val_output4_acc: 0.8958 - val_output5_acc: 0.9575

# %% [markdown]
# ## Testing the Model

# %%
# !python main.py --lang urdu --mode test --phonetic true --freezing true
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:125: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:127: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# ...

# %% [markdown]
# * Average precision score, micro-averaged over all classes: 0.031849029929303475
# * Average precision score, micro-averaged over all classes: 0.05581305047032416
# * Average precision score, micro-averaged over all classes: 0.16493907694636087
# * Average precision score, micro-averaged over all classes: 0.07484283119527992
# * Average precision score, micro-averaged over all classes: 0.1339942775094234
# * Average precision score, micro-averaged over all classes: 0.7154971754964659

# %%
# !python main.py --lang urdu --mode predict --phonetic true --freezing true #predict
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:125: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:127: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# ...
