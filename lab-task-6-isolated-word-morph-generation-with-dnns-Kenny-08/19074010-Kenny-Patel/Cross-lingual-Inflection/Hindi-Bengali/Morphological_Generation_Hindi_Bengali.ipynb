# %%
# !git clone https://github.com/sigmorphon/crosslingual-inflection-baseline.git
# Out:
# Cloning into 'crosslingual-inflection-baseline'...
# remote: Enumerating objects: 108, done.
# remote: Total 108 (delta 0), reused 0 (delta 0), pack-reused 108
# Receiving objects: 100% (108/108), 62.34 MiB | 24.89 MiB/s, done.
# Resolving deltas: 100% (52/52), done.

# %%
cd /content/crosslingual-inflection-baseline
# Out:
# /content/crosslingual-inflection-baseline

# %%
# !bash scripts/run-task1-tag.sh soft hindi--bengali
# Out:
# 2021-03-23 15:42:07 INFO: command line argument: seed - 0
# 2021-03-23 15:42:07 INFO: command line argument: dataset - <Data.sigmorphon19task1: 'sigmorphon19task1'>
# 2021-03-23 15:42:07 INFO: command line argument: train - ['sample/task1/hindi--bengali/hindi-train-high', 'sample/task1/hindi--bengali/bengali-train-low']
# 2021-03-23 15:42:07 INFO: command line argument: dev - 'sample/task1/hindi--bengali/bengali-dev'
# 2021-03-23 15:42:07 INFO: command line argument: test - None
# 2021-03-23 15:42:07 INFO: command line argument: model - 'model/sigmorphon19/task1/tag-soft/hindi--bengali'
# 2021-03-23 15:42:07 INFO: command line argument: load - ''
# 2021-03-23 15:42:07 INFO: command line argument: bs - 20
# 2021-03-23 15:42:07 INFO: command line argument: epochs - 150
# 2021-03-23 15:42:07 INFO: command line argument: optimizer - 'Adam'
# 2021-03-23 15:42:07 INFO: command line argument: lr - 0.001
# 2021-03-23 15:42:07 INFO: command line argument: min_lr - 1e-05
# ...
